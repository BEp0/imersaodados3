# %% [markdown]
# <a href="https://colab.research.google.com/github/BEp0/imersaodados3/blob/main/dia5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url_dados = 'https://github.com/BEp0/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
# reatribuindo o nome da coluna
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace=True) # inplace substitui o data frame, não roda as cedulas de cima
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dose = dados['dose']
tempo = dados['tempo']
composto = dados['composto']
pd.crosstab(dose, tempo)
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()
corr_celular = dados.loc[:, 'c-0':'c-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
# importando a base de dados "RESULTADOS"
dados_resultados = pd.read_csv('https://github.com/BEp0/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique() # saber quantos valores eu tenho
# ativado = 1
# não ativado = 0
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False) # pegamos somente os valores numericos
contagem_moa # contamos
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa # o mesmo resultado, mas aqui excluimos a 1º coluna
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1) # soma as vezes que foi ativo
dados_resultados['ativos_moa'] = (dados_resultados['n_moa'] != 0) # informa se foi ativo
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativos_moa
# 0  id_000644bb2                            0  ...      1        True
# 1  id_000779bfc                            0  ...      0       False
# 2  id_000a6266a                            0  ...      3        True
# 3  id_0015fd391                            0  ...      0       False
# 4  id_001626bd3                            0  ...      1        True
#
# [5 rows x 209 columns]

# %%
cont = 0
for i in dados_resultados['ativos_moa']:
  if i == False:
    cont += 1
cont # contamos quantos 0 tem
# Out:
# 9367

# %%
dados_merge = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativos_moa']], on='id') # cria a base de dados com as colunas n_moa e ativos_moa
dados_merge.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativos_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1        True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0       False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3        True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0       False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1        True
#
# [5 rows x 879 columns]

# %%
dados_merge.query('tratamento == "com_controle"')['ativos_moa'].value_counts() # mostra se é tudo falso
# Out:
# False    1866
# Name: ativos_moa, dtype: int64

# %%
dados_merge.query('tratamento == "com_droga"')['ativos_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativos_moa, dtype: int64

# %%
sns.boxplot(data= dados_merge, y='g-0', x='composto')

# %%
com_principal = dados_merge['composto'].value_counts().index[:5]
sns.set()
plt.figure(figsize=(12, 8))
sns.boxplot(data = dados_merge.query('composto in @com_principal'), y='g-0', x='composto', hue='ativos_moa')

# %%
dados_merge.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativos_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1        True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0       False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3        True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0       False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1        True
#
# [5 rows x 879 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativos_moa
# 0  id_000644bb2                            0  ...      1        True
# 1  id_000779bfc                            0  ...      0       False
# 2  id_000a6266a                            0  ...      3        True
# 3  id_0015fd391                            0  ...      0       False
# 4  id_001626bd3                            0  ...      1        True
#
# [5 rows x 209 columns]

# %%
# vamos usar a regreção logistica
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_merge.select_dtypes('float64') # expressão gênica e viabilidade celular
y = dados_merge['ativos_moa']

# precisamos separar um conjunto de dados pra treino e outro pra teste
# separamos para verificar outros dados que o programa nunca viu antes, para saber se funcionou ou não
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=376, stratify=y)

modelo_regressao = LogisticRegression(max_iter=1000)
modelo_regressao.fit(x_treino, y_treino) # treinamento
modelo_regressao.score(x_teste, y_teste) # verifica a acurácia
# Out:
# 0.6264959059416334

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dumy = DummyClassifier('most_frequent')
modelo_dumy.fit(x_treino, y_treino)
previsao_dumy = modelo_dumy.predict(x_teste)
accuracy_score(y_teste, previsao_dumy) # mostra se eu simplesmente chutasse a precisão seria 60%, logo nosso programa anterior não seria muito eficaz
# Out:
# 0.6067604450976275

# %%
dados_merge['ativos_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativos_moa, dtype: float64

# %%
# modelo de arvore de decisão
from sklearn.tree import DecisionTreeClassifier

x = dados_merge.select_dtypes('float64') # expressão gênica e viabilidade celular
y = dados_merge['ativos_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=376, stratify=y)

teste=[]
treino=[]

for i in range(1, 15):
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6206172580306529,
#  0.6204073063195465,
#  0.6185177409195884,
#  0.6208272097417594,
#  0.6210371614528658,
#  0.6166281755196305,
#  0.6143187066974596,
#  0.6094898173420114,
#  0.5973126180978375,
#  0.5973126180978375,
#  0.5960529078311988]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.6895176106241142,
#  0.706892026665267,
#  0.7292530575822791,
#  0.7529788462547897,
#  0.7769670883418194,
#  0.7993281192588315]

# %%
sns.lineplot(x = range(1, 15), y= teste, label='teste')
sns.lineplot(x = range(1, 15), y= treino, label='treino')

# %%
pd.get_dummies(dados_merge['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_merge, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
# modelo de arvore de decisão
from sklearn.ensemble import RandomForestClassifier


x = dados_merge.drop(['id', 'n_moa', 'ativos_moa', 'composto'], axis=1) # expressão gênica e viabilidade celular
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_merge['ativos_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=376, stratify=y)

modelo_Random = LogisticRegression(max_iter=1000)
modelo_Random.fit(x_treino, y_treino) # treinamento
modelo_Random.score(x_teste, y_teste) # verifica a acurácia
# Out:
# 0.6640772622296872
